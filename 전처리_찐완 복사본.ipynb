# %%
import requests
from bs4 import BeautifulSoup
import time
import re
from tqdm import tqdm

# 페이지 번호 생성하는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num + 1
    else:
        return num + 9 * (num - 1)

# 검색 URL 생성하는 함수
def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(start_page)
        print("생성된 URL: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성된 URLs: ", urls)
        return urls    
    
## 텍스트 전처리 사용자 정의함수(UDF of text pre-processing)
def text_preprocessor(s):
    import re
    
    ## (1) [], (), {}, <> 괄호와 괄호 안 문자 제거하기
    pattern = r'\([^)]*\)'  # ()
    s = re.sub(pattern=pattern, repl='', string=s)
    
    pattern = r'\[[^)]*\]'  # []
    s = re.sub(pattern=pattern, repl='', string=s)
    
    pattern = r'\<[^)]*\>'  # <>
    s = re.sub(pattern=pattern, repl='', string=s)
    
    pattern = r'\{[^)]*\}'  # {}
    s = re.sub(pattern=pattern, repl='', string=s)
    
    ## (2) '...외', '...총' 제거하기
    s = s.replace('...외', ' ')
    s = s.replace('...총', ' ')
    
    ## (3) 특수문자 제거
    pattern = r'[^a-zA-Z가-힣]'
    s = re.sub(pattern=pattern, repl=' ', string=s)
    
    ## (4) 단위 제거: cm, km, etc.
    units = ['mm', 'cm', 'km', 'ml', 'kg', 'g']
    for unit in units:
        s = s.lower() # 대문자를 소문자로 변환
        s = s.replace(unit, '')
        
    # (5) 공백 기준으로 분할하기
    s_split = s.split()
    
    # (6) 글자 1개만 있으면 제외하기
    s_list = []
    for word in s_split:
        if len(word) !=1:
            s_list.append(word)
            
    return s_list

# 검색어와 페이지 입력 받기
search = input("검색어를 입력하세요:")
start_page = int(input("\n크롤링을 시작할 페이지를 :"))
end_page = int(input("\n크롤링을 종료할 페이지를 :"))

# Naver 검색 URL 생성
urls = makeUrl(search, start_page, end_page)

# 기사 URL 크롤링
article_urls = []
for url in urls:
    article_urls.extend(articles_crawler(url))

# Naver 뉴스 URL 필터링
final_urls = [url for url in article_urls if "news.naver.com" in url]

# 데이터 저장을 위한 리스트 초기화
news_titles = []
news_contents = []

# 뉴스 내용 추출하는 함수
def extract_news_content(url):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}
    news = requests.get(url, headers=headers)
    news_html = BeautifulSoup(news.text, "html.parser")
    title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    if title is None:
        title = news_html.select_one("#content > div.end_ct > div > h2")
    content = news_html.select("article#dic_area")
    if not content:
        content = news_html.select("#articleBody")
    title = re.sub(pattern='<[^>]*>', repl='', string=str(title))
    content = re.sub(pattern='<[^>]*>', repl='', string=''.join(map(str, content)))
    content = content.replace("""[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}""", '')
    return title, content

# 뉴스 내용 추출
for url in tqdm(final_urls):
    title, content = extract_news_content(url)
    news_titles.append(title)
    news_contents.append(content)

# 결과 출력
def words_tokonizer(text):
    from konlpy.tag import Kkma # 한국어nlp
    kkma = Kkma()
    
    words = []
    
    
    s_list = text_preprocessor(text)
    
    # 태깅
    for s in s_list:
        words_ = kkma.pos(s)   
        
        # 인덱싱
        for word in words_:
            if word[1] == 'NNG':
                words.append(word[0])
            
    return words

# 결과 나옴
print("\n검색된 기사 수: ", len(news_titles))

for n, (title, content) in enumerate(zip(news_titles, news_contents), start=1):
    if title == None:
        continue
    print(f"\n{n}번 뉴스 제목: {words_tokonizer(title)}")
    print(f"뉴스 내용:\n{words_tokonizer(content)}\n")
# Out:
# 생성된 URLs:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=축구&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=축구&start=11']
# 100%|██████████| 20/20 [00:07<00:00,  2.79it/s]
# 검색된 기사 수:  20
#
# 1번 뉴스 제목: ['축구', '배드민턴', '안', '양궁', '김우진', '항저우', '주목', '스타', '선정']
# 뉴스 내용:
# ['파리', '제', '르', '강인', '보루', '시', '챔피언', '스리', '경기', '출전', '모습', '로이터', '연합', '뉴스', '항저우', '아시안', '게임', '출격', '축구', '대표팀', '강인', '배드민턴', '안', '양궁', '김우진', '아시안', '게임', '조직', '위원회', '선정', '주목', '선수', '선정', '항저우', '아시안', '게임', '조직위', '공식', '개막', '사흘', '이번', '대회', '주목', '선수', '소개', '한국', '선수', '안', '김우진', '명단', '조직위', '강인', '한국', '월드컵', '결승', '행', '리', '메시', '포', '바', '골든', '볼', '소개', '올해', '세인', '스타', '군단', '이자', '프랑스', '리그', '챔피언', '파리', '생', '합류', '강인', '항저우', '입국', '남자', '축구', '조', '리그', '대표팀', '합류', '예정', '한국', '조', '리그', '차전', '파', '중국', '오픈', '우승', '인천', '공항', '귀국', '안', '뉴스', '안', '선', '세', '여자', '단식', '세계', '랭킹', '위', '한국', '여자', '선수', '최초', '세계', '선수권', '금메달', '소개', '조직위', '안', '올해', '차례', '투어', '대회', '우승', '세계', '챔피언', '일본', '야마', '구치', '올림픽', '금메달', '리스트', '중국', '상대', '승리', '야마', '구치', '안', '배드민턴', '여자', '단식', '천왕', '선수', '로', '지난해', '안', '선수', '약', '모습', '올해', '우위', '지난달', '서울', '목동', '종합', '운동장', '현대자동차', '정', '구배', '한국', '양궁', '대회', '출전', '김우진', '뉴스', '김우진', '양궁', '남자', '커브', '종목', '유력', '우승', '후보', '평가', '조직위', '세인', '김우진', '리', '올림픽', '올림픽', '남자', '단체전', '금메달', '목', '아시안', '게임', '개인전', '우승', '세계', '랭킹', '아시아', '위', '소개', '김우진', '광저우', '아시안', '게임', '개인전', '단체전', '자', '카르타', '팔렘방', '대회', '개인전', '이번', '대회', '통산', '아시안', '게임', '금메달']
#
#
# 2번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 3번 뉴스 제목: ['우', '홍', '콩', '축구', '무혈', '입성']
# 뉴스 내용:
# ['항저우', '아시안', '게임', '개회식', '리허설', '중국', '항저우', '올림픽', '스포츠', '센터', '스타디움', '주변', '출입', '통제', '연합', '뉴스', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '조', '진출', '팀', '확정', '황', '일', '발생', '항저우', '아시안', '게임', '공식', '홈페이지', '대진', '기존', '니스', '과', '시리아', '홍', '콩과', '우', '베', '키스', '의', '이름', '이번', '대회', '남자', '축구', '조', '조', '편성', '위', '국가', '성적', '강', '체제', '철수', '팀', '체제', '유지', '홍', '콩과', '우', '베', '키스', '자동', '강', '진출', '행운', '중국', '시', '스포츠', '니스', '해당', '연령', '선수', '수급', '시리아', '경우', '대회', '준비', '위', '이번', '대회', '출전', '연령', '선수', '육성', '투자', '우', '베', '키스', '유력', '한국', '라이벌', '기도', '우', '베', '키스', '의', '무혈', '입성', '대회', '결과', '영향', '주목']
#
#
# 4번 뉴스 제목: ['최근', '불법', '산림', '벌채', '축구장', '규모', '훼손']
# 뉴스 내용:
# ['용', '의원', '불법', '벌채', '피해액', '불법', '벌채', '규모', '피해액', '지역', '불법', '벌채', '환경', '파괴', '행위', '단속', '확대', '처벌', '강화', '김', '양수', '기자', '최근', '불법', '산림', '벌채', '축구장', '규모', '산림', '훼손', '불법', '벌채', '피해', '규모', '곳', '지역', '확인', '국회', '농림', '축산', '식품', '해양', '수산', '위원회', '국민', '힘', '용', '의원', '산림청', '제출', '공개', '최근', '산림', '불법', '벌채', '단속', '현황', '자료', '불법', '벌채', '단속', '건수', '피해', '면적', '축구장', '피해액', '만원', '확인', '연도별', '피해액', '만원', '만원', '만원', '만원', '만원', '만원', '증가', '조사', '지역별', '산림', '불법', '벌채', '단속', '건수', '충남', '전', '북도', '전', '건의', '순', '집계', '피해', '면적', '충남', '전', '북도', '전', '충북', '불법', '벌채', '지역별', '피해액', '경우', '만원', '만원', '충남', '만원', '전', '만원', '만원', '인천시', '만원', '전', '북도', '만원', '조사', '산림', '불법', '벌채', '단속', '조치', '현황', '불구속', '송치', '전체', '차지', '관할지', '자체', '경찰', '타', '기관', '이송', '의원', '불법', '산림', '벌채', '산림', '자원', '고갈', '야생', '동물', '서식지', '파괴', '대기', '탄소', '흡수', '감소', '환경', '파괴', '행위', '라', '훼손', '산림', '원래', '모습', '선', '시간', '비용', '필요', '불법', '행위', '발생', '사전', '차단', '예방', '중요', '의원', '국가', '지방', '자치', '단체', '전담', '단속반', '운영', '인력', '확대', '행위자', '처벌', '강화', '국민', '인식', '전환', '위', '홍보', '활동', '강화', '산림', '불법', '행위', '근절', '다각적', '노력', '필요', '지적']
#
#
# 5번 뉴스 제목: ['치킨', '이', '스타', '축구', '대표팀', '응원', '이벤트', '실시']
# 뉴스 내용:
# ['신', '메뉴', '마법', '터', '대표', '메뉴', '경품', '제공', '치킨', '오후', '국가', '대표', '축구', '경기', '축구', '전문', '유', '채널', '이', '스타', '치킨', '경품', '이벤트', '김진희', '기자', '치킨', '신', '메뉴', '마법', '과', '축구', '국가', '대표팀', '응원', '치킨', '오후', '국가', '대표', '축구', '경기', '축구', '전문', '유', '채널', '이', '스타', '치킨', '경품', '이벤트', '진행', '이번', '이벤트', '축구', '경기', '이', '스타', '후', '토크', '코너', '진행', '축구', '치킨', '이유', '글', '작성', '참여', '가능', '이벤트', '당첨', '고객', '치킨', '신', '메뉴인', '치킨', '마법', '콜라', '대표', '메뉴인', '치킨', '콜라', '치킨', '맛', '초', '킹', '콜라', '제공', '치킨', '관계자', '국가', '대표팀', '응원', '승리', '기원', '마음', '주요', '스포츠', '경기', '치킨', '선택', '주시', '고객', '감사', '기획', '이벤트', '라', '고객', '소통', '공감대', '형성', '다양', '이벤트', '마련', '계획']
#
#
# 6번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 7번 뉴스 제목: ['아시안', '게임', '태극전사', '약속', '항저우', '출발', '축구', '황', '선', '홍', '호', '팀', '웨이트', '대파', '기분', '출발']
# 뉴스 내용:
# ['한국', '종목', '역대', '최다', '파견', '금메달', '이상', '종합', '순위', '달성', '목표', '스포츠', '선수', '국민', '행복', '항저우', '아시안', '게임', '출전', '대한민국', '선수단', '본진', '인천', '국제공항', '중국', '항저우', '출국', '기념', '촬영', '연합', '뉴스', '항저우', '아시안', '게임', '출전', '한국', '선수단', '본진', '약속', '중국', '항저우', '도착', '한국', '선수단', '다음', '일', '일간', '항저우', '도시', '그동안', '피땀', '실력', '예정', '대한민국', '선수단', '본진', '오전', '인천', '국제공항', '항저우', '출국', '이날', '출국', '본진', '윤', '한국', '선수단', '장', '재근', '진천', '국가', '대표', '선수촌', '본부', '임원', '명이', '포함', '한국', '테니스', '간판', '선수', '권', '순', '우가', '속', '테니스', '대표팀', '사격', '대표팀', '하키', '대표팀', '스케이트', '보드', '대표팀', '선수', '항저우', '행', '비행기', '선수단', '임원', '태극기', '선전', '기원', '현수막', '코리아', '파이', '항저우', '아시안', '게임', '출전', '대한민국', '선수단', '본진', '인천', '국제공항', '중국', '출국', '기념', '촬영', '연합', '뉴스', '한국', '이번', '아시안', '게임', '역대', '최다', '규모', '명의', '선수단', '파견', '선수', '중국', '저장성', '성도', '항저우', '진화', '원저우', '후', '샤오싱', '도시', '경기', '예정', '한국', '선수단', '이번', '대회', '금메달', '최대', '이상', '종합', '순위', '위', '목표', '한국', '자', '카르타', '팔렘방', '아시안', '게임', '당시', '금메달', '은메달', '동메달', '개로', '종합', '위', '차지', '윤', '한국', '선수단', '장', '한국', '선수단', '실력', '종합', '목표', '결과', '스포츠', '국민', '선수', '행복', '한국', '선수단', '항저우', '시내', '아시안', '게임', '선수촌', '공식', '입', '촌', '행사', '본격적', '대회', '준비', '한국', '선수단', '공식', '경기', '일정', '일', '시작', '황', '선', '홍', '감독', '남자', '축구', '대표팀', '중국', '진화', '스타디움', '웨이트', '와의', '조', '리그', '차전', '승리', '남자', '축구', '대표팀', '공격', '미드필더', '정우', '영', '해트', '트릭', '포함', '골', '기분', '승', '신고']
#
#
# 8번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 9번 뉴스 제목: ['축구', '가자', '광주', '경기', '무패', '행진', '천여', '좌석', '매진']
# 뉴스 내용:
# ['전', '북', '현대전', '경기', '연속', '무패', '도전', '광주', '홈페이지', '전', '좌석', '매진', '창이', '뉴스', '김', '태성', '기자', '광주', '축구', '전용', '구장', '전', '좌석', '매진', '프로', '축구', '광주', '최근', '경기', '무패', '행진', '이번', '주말', '광주', '홈경기', '전', '좌석', '매진', '광주', '전날', '오후', '시', '홈페이지', '전', '북전', '매진', '안내', '타이틀', '팝업', '창', '본문', '오후', '경기', '당일', '현장', '매표소', '티켓', '구매', '무료', '입장', '불가', '온라인', '예매', '티켓', '교환', '가능', '광주', '축구', '전용', '구장', '좌석', '석', '보유', '일부', '보강', '공사', '중인', '좌석', '제외', '이날', '석이', '매진', '광주', '강원', '상대', '무승부', '기록', '이후', '무패', '행진', '경기', '승점', '점', '리그', '위', '기염', '일', '창단', '처음', '서울', '원정', '경기', '승리', '따내기', '광주', '홈', '전', '북', '현대', '상대', '경기', '연속', '무패', '도전', '축구', '팬', '광주', '부', '리그', '무대', '첫해', '기대', '이상', '성적', '성적', '창단', '아시아', '축구', '연맹', '챔피언', '스리', '진출', '광주', '관계자', '올해', '매진', '감독', '선수', '기대', '이상', '성적', '경기', '광주', '시민']
#
#
# 10번 뉴스 제목: ['국제무대', '복귀', '북한', '남자', '축구', '대', '완승']
# 뉴스 내용:
# ['전반', '경기', '대', '북한', '대규모', '아시안', '게임', '선수단', '축구', '북한', '남자', '축구', '대표팀', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '예선', '차전', '대', '올림픽', '종합', '대회', '분류', '아시안', '게임', '북한', '축구', '모습', '자', '카르타', '팔렘방', '아시안', '게임', '이후', '만이', '북한', '이날', '경기', '전반', '조국', '선제', '골', '기선', '제압', '조국', '페널티', '박스', '안', '오른발', '슈팅', '공이', '대', '수비수', '골문', '안', '전반', '추가', '골', '백충', '대', '왼쪽', '측면', '돌파', '골대', '공', '김국', '진이', '발리슛', '골문', '북한', '이날', '전후반', '일방적', '대', '북한', '코로나', '이유', '올림픽', '일방적', '불참', '국제', '올림픽', '위원', '회로', '자격', '정지', '처분', '지난해', '자격', '정지', '해제', '올해', '종목별', '국제', '대회', '모습', '북한', '항저우', '아시안', '게임', '종목', '여자', '남자', '명의', '선수단', '파견', '냉전', '국제', '정세', '속', '우방', '힘', '동시', '지리적', '인접', '대규모', '선수단', '파견', '영향', '풀이', '북한', '이번', '축구', '등록', '북한', '역대', '아시안', '게임', '축구', '금메달', '개', '개', '획득', '그중', '개', '여자', '축', '국제', '대회', '복귀', '전', '기분', '북한', '남자', '축구', '대표팀', '키', '르', '인도네시아', '차례', '오후', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '북한', '대', '경기', '북한', '조국', '선제', '골', '동료']
#
#
# 11번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 12번 뉴스 제목: ['남자', '축구', '황', '선', '홍', '차전', '웨이트', '대파', '정우', '영', '해트', '트릭']
# 뉴스 내용:
# ['오후', '중국', '저장성', '진화', '진화', '스타디움', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '한국', '웨이트', '경기', '정우', '영이', '전반', '선제', '골', '환호', '연합', '뉴스', '오후', '중국', '저장성', '진화', '진화', '스타디움', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '한국', '웨이트', '경기', '전반전', '선제', '골', '골', '정우', '영', '골', '조영', '연합', '뉴스', '아시안', '게임', '연속', '금메달', '도전', '한국', '남자', '축구', '대표팀', '조', '리그', '차전', '폭죽', '대승', '장식', '황', '선', '홍', '감독', '한국', '중국', '저장성', '진화', '스포츠', '센터', '스타디움', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '웨이트', '경기', '전반', '정우', '영', '선제', '골', '시작', '전반', '후반', '골', '화력', '과시', '정우', '영', '전반', '후반', '골', '이날', '경기', '해트', '트릭', '달성', '조영', '전반', '분과', '후반', '득점', '멀티', '전반', '백승', '후반', '원', '상', '후반', '박재', '후반', '추가', '시간', '안', '재준', '골', '황', '선', '홍', '감독', '이날', '최전방', '조영', '영준', '배치', '정우', '영', '원', '상', '날개', '정호', '연', '주장', '백승', '호가', '중원', '가운데', '박', '박진', '이한', '황', '재원', '포백', '수비진', '구성', '골키퍼', '장갑', '이', '한국', '전반', '정우', '영이', '상대', '수비', '발', '굴절', '공', '침착', '오른발', '선제', '골', '마무리', '출발', '전반', '원', '상의', '슛', '골대', '문전', '쇄도', '조영', '오른발', '중거리', '포로', '연결', '전반', '막판', '백승', '호가', '페널티', '지역', '왼쪽', '프리킥', '대포알', '오른발', '슈팅', '전반', '역습', '상황', '정우', '영이', '골', '추가', '전반', '전반', '골', '한국', '승리', '경기', '우리나라', '후반', '골', '후반', '조영', '슈팅', '상대', '골키퍼', '정우', '영이', '해트', '트릭', '완성', '후반', '원', '상', '왼발', '슈팅', '황', '선', '홍', '감독', '후반', '영준', '원', '상', '황', '재원', '박재', '안', '재준', '투입', '후반', '정우', '영', '홍', '현', '우리나라', '이후', '조영', '박재', '안', '재준', '골', '차전', '대승', '마무리', '경기', '태국', '바레인', '우리나라', '위', '승', '한국', '태국', '조', '리그', '차전']
#
#
# 13번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 14번 뉴스 제목: ['축구', '경기', '결과', '치킨', '교', '촌', '치킨', '응원', '이벤트']
# 뉴스 내용:
# ['류', '영', '기자', '치킨', '랜', '차', '이즈', '교', '촌', '치킨', '운영', '교', '촌', '에프', '앤', '비', '아시아', '최대', '스포츠', '축제', '기간', '교', '촌', '치킨', '고객', '대상', '치킨', '교환권', '증정', '이벤트', '이번', '이벤트', '이달', '일', '일', '중국', '항저우', '국제', '스포츠', '대회', '응원', '열기', '국내', '스포츠', '팬', '즐거움', '더하기', '기획', '교', '촌은', '일', '교', '촌', '치킨', '남자', '축구', '여자', '축구', '야구', '종목', '예정', '경기', '결과', '예측', '응원', '메시지', '작성', '고객', '치킨', '교환권', '선물', '종목별', '경기', '결과', '예측', '회원', '승부', '추첨', '허니콤', '제품', '교환권', '레드', '제품', '교환권', '반반', '제품', '교환권', '제공', '응원', '메시지', '회원', '응원', '추첨', '제품', '교환권', '증정', '이번', '이벤트', '상품', '경기', '관람', '고객', '교', '촌', '치킨', '대표', '메뉴', '로', '구성', '이벤트', '종목별', '당첨자', '중복', '선정', '가능', '당첨자', '발표']
#
#
# 15번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 16번 뉴스 제목: ['축구', '웨이트', '중계', '시청률', '싹쓸이']
# 뉴스 내용:
# []
#
#
# 17번 뉴스 제목: []
# 뉴스 내용:
# []
#
#
# 18번 뉴스 제목: ['웨이트', '대폭격', '축구', '게임', '연패', '출발']
# 뉴스 내용:
# ['조', '리그', '차전', '대승', '정우', '영', '해트', '트릭', '조영', '환호', '국제', '대회', '승', '신고', '우', '베', '홍', '콩', '확정', '정우', '영이', '웨이트', '와의', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '골', '한국', '벤치', '포효', '이날', '골', '해트', '트릭', '달성', '정우', '영', '한국', '대승', '조영', '골', '원', '상도', '골', '축구', '협회', '제공', '아시안', '게임', '남자', '축구', '역', '사상', '최초', '대회', '연패', '도전', '한국', '항저우', '경기', '대승', '장식', '순항', '황', '선', '홍', '감독', '지휘', '한국', '대표팀', '중국', '저장성', '진화', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '웨이트', '와의', '경기', '완승', '항저우', '아시안', '게임', '공식', '개막', '축구', '배구', '비치', '발리', '크리켓', '일부', '종목', '일', '경기', '일정', '한국', '경기', '시작', '정우', '영', '선제', '골', '신호탄', '웨이트', '골문', '대회', '첫판', '차', '압승', '장식', '한국', '아시안', '게임', '역대', '최다', '승리', '한국', '히', '시마', '대회', '조', '리그', '차전', '상대', '팔', '당시', '대표팀', '스트라이커', '감독', '혼자', '골', '한국', '히', '시마', '대회', '당시', '조', '리그', '동메달', '결정전', '웨이트', '위', '정우', '영', '전반', '추가', '시간', '후반', '상대', '골', '망', '해트', '트릭', '기록', '후반', '홍', '석', '교체', '조영', '골', '주장', '백승', '원', '상', '박재', '안', '재준', '명이', '골', '맛', '황', '선', '홍', '호', '대회', '경기', '선수', '득점', '포', '가동', '이날', '경기', '전', '경기력', '의문', '부호', '감독', '파리', '제', '르', '소속', '강인', '대표팀', '합류', '전', '대승', '강인', '도', '르', '와의', '유럽', '축구', '연맹', '챔피언', '스리', '조', '리그', '경기', '프랑스', '파리', '항저우', '강인', '조', '리그', '차전', '바레인', '전', '출전', '조의', '바레인', '태국', '경기', '팀', '골', '태국', '후반', '추가', '시간', '극장', '골', '패배', '한국', '태국', '조', '리그', '차전', '아시안', '게임', '통산', '최다', '우승', '국인', '한국', '인천', '자', '카르타', '팔렘방', '대회', '연속', '우승', '종합', '국제', '대회', '참가', '북한', '이날', '경기', '대', '전반', '조국', '선제', '골', '김국', '진이', '추가', '골', '북한', '대학생', '선수', '아마추어', '팀', '대', '상대', '우세', '경기', '조의', '홍', '콩과', '우', '베', '키스', '강', '무혈', '입성', '조', '리그', '조', '니스', '과', '시리아', '출전', '포기', '일', '항저우', '아시안', '게임', '공식', '홈페이지', '남자', '축구', '조', '리그', '조', '포함', '니스', '과', '시리아', '편성표', '니스', '재정난', '선수', '수급', '문제', '시리아', '대회', '조직위', '마찰', '당초', '참가', '이번', '대회', '남자', '축구', '조로', '편성', '조', '포함', '나머지', '조', '나라', '조', '리그', '팀', '팀', '성적', '팀', '토너먼트', '방식', '팀', '남', '조', '홍', '콩과', '우', '베', '키스', '강']
#
#
# 19번 뉴스 제목: ['북한', '남자', '축구', '국제무대', '복귀', '전서', '대', '완승']
# 뉴스 내용:
# ['종합', '대회', '축구', '국제', '대회', '복귀', '북한', '선제', '골', '류', '영', '기자', '오후', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '북한', '대', '경기', '북한', '조국', '선제', '골', '동료', '남직', '기자', '북한', '남자', '축구', '대표팀', '종합', '대회', '이자', '국제무대', '복귀', '전', '완승', '북한', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '예선', '차전', '대', '전반', '조국', '선제', '골', '김국', '진이', '추가', '골', '올림픽', '종합', '대회', '분류', '아시안', '게임', '북한', '축구', '모습', '자', '카르타', '팔렘방', '아시안', '게임', '이후', '만이', '북한', '아시아', '축구', '연맹', '이하', '대회', '이후', '국제', '무대', '복귀', '북한', '신종', '코로나', '바', '감염증', '이유', '올림픽', '일방적', '불참', '국제', '올림픽', '위원', '회로', '자격', '정지', '처분', '지난해', '자격', '정지', '해제', '올해', '종목별', '국제', '대회', '모습', '북한', '항저우', '아시안', '게임', '규모', '선수', '파견', '국제', '축구', '연맹', '랭킹', '위의', '대', '상대', '경기', '여', '전력', '평가', '북한', '이날', '경기', '상대', '압도', '포메이션', '북한', '오른쪽', '날개', '백충', '대', '측면', '돌파', '투', '톱', '조국', '김', '지원', '형태', '공격', '구사', '백충', '수비', '왼쪽', '날개', '리', '일성', '활로', '인공기', '응원', '북한', '응원단', '류', '영', '기자', '오후', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '북한', '대', '경기', '북한', '응원단', '응원', '북한', '전반', '조국', '선제', '골', '기선', '제압', '조국', '페널티', '박스', '안', '오른발', '슈팅', '공이', '대', '수비수', '골문', '안', '이날', '경기장', '라', '선수', '북한', '여성', '응원단', '손뼉', '환호', '추가', '골', '전반', '백충', '대', '왼쪽', '측면', '돌파', '크로스', '김국', '진이', '발리슛', '골문', '만이', '전반', '추가', '시간', '슈팅', '정도', '북한', '전반', '일방적', '상대', '북한', '추가', '골', '류', '영', '기자', '오후', '중국', '저장성', '진화', '저장성', '사범대', '동쪽', '경기장', '항저우', '아시안', '게임', '남자', '축구', '조', '리그', '차전', '북한', '대', '경기', '북한', '김국', '진이', '추가', '골', '북한', '후반', '주도권', '골', '후반', '페널티', '박스', '왼쪽', '앞', '프리킥', '강국', '철', '중앙', '박', '광천', '강', '헤더', '공', '크로스바', '후반', '조국', '에어리어', '앞', '돌파', '왼발', '슈팅', '수비벽', '대', '후반', '추가', '시간', '전', '보여', '유가', '북한', '골키퍼', '슛', '크로스바', '위로', '득점', '실패', '국제', '대회', '복귀', '전', '기분', '북한', '키', '르', '인도네시아', '차례']
#
#
# 20번 뉴스 제목: ['독일', '축구', '대표팀', '감독', '유로']
# 뉴스 내용:
# ['이율', '특파원', '전차', '군단', '독일', '축구', '대표팀', '신임', '감독', '명장', '율', '리', '안', '만이', '낙점', '독일', '피', '율', '리', '안', '독일', '축구', '대표팀', '신임', '감독', '연합', '뉴스', '자료', '사진', '재판매', '금지', '독일', '축구', '협회', '감독', '베', '엔도', '로프', '회장', '루', '디', '독일', '국가', '대표팀', '단장', '회동', '도르프', '회장', '내용', '대화', '양측', '계약', '세부', '내용', '협의', '중인', '감독', '급여', '유로', '추산', '감독', '일본', '평가전', '완패', '여파', '속', '경질', '한지', '리', '감독', '후임', '내년', '독일', '유럽', '축구', '선수권', '대회', '전차', '군단', '카타르', '월드컵', '조', '리그', '탈락', '이후', '신임', '리', '감독', '불명예', '퇴진', '일본', '매치', '연패', '부진', '독일', '축구', '대표팀', '전임', '감독', '도입', '이후', '사령탑', '경질', '최초', '사례', '리', '감독', '경질', '이후', '독일', '축구', '대표팀', '프랑스', '승리', '경기', '승전고', '전차', '군단', '프랑스', '제압', '감독', '호', '라이프', '히', '성과', '명장', '독일', '최고', '명문', '클럽', '사령탑', '인물', '지휘봉', '감독', '시즌', '독일', '스리', '우승', '유럽', '축구', '연맹', '챔피언', '스리', '포', '칼', '등에', '선', '성적', '경질', '만과', '계약', '기간', '계약', '해지', '축구', '대표팀', '행', '방해', '신임', '감독', '독일', '축구', '대표팀', '멕시코', '연말', '오스트', '리', '평가전']
